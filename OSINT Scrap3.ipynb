# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import collections
import pandas as pd

# %% [markdown]
# # 1er exmple de scraping d'1 table

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area
# https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2016-2017
# http://pokemondb.net/pokedex/national

# %%
# Réccuperer le contenu d'1tableau et le stocker ds 1df

url = 'https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area'
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   List of Asian countries by area - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"8779e603-96e9-4147-841f-0038ad36da8a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_Asian_countries_by_area","wgTitle":"List of Asian countries by area","wgCurRevisionId":990004787,"wgRevisionId":990004787,"wgArticleId":47659173,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Arti
# ...

# %%
# On cherche à l'aide l'inspecteur chrome 'table class = wikitable sortable'
my_table = soup.find('table', {'class' : 'wikitable sortable'})
my_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Country
# </th>
# <th>Area (km²)
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon" style="display:inline-block;width:25px;"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/></span> <a href="/wiki/Russia" title="Russia">Russia</a>*
# </td>
# <td>13,000,000
# </td>
# <td>17,125,191 km² including <a href="/wiki/European_Russia" title="European Russia">European Russia</a><sup class="reference" id="cite_ref-russiaTotalAreaByCIA_1-0"><a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a></sup>
# ...

# %%
# Ns allons chercher à extraire ts les liens <a> href à l'aide de find_all()
links = my_table.find_all('a')
links
# Out:
# [<a href="/wiki/Russia" title="Russia">Russia</a>,
#  <a href="/wiki/European_Russia" title="European Russia">European Russia</a>,
#  <a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a>,
#  <a href="/wiki/China" title="China">China</a>,
#  <a href="/wiki/Hong_Kong" title="Hong Kong">Hong Kong</a>,
#  <a href="/wiki/Macau" title="Macau">Macau</a>,
#  <a href="/wiki/India" title="India">India</a>,
#  <a href="/wiki/Kazakhstan" title="Kazakhstan">Kazakhstan</a>,
#  <a href="/wiki/Saudi_Arabia" title="Saudi Arabia">Saudi Arabia</a>,
#  <a href="/wiki/Iran" title="Iran">Iran</a>,
#  <a href="/wiki/Mongolia" title="Mongolia">Mongolia</a>,
#  <a href="/wiki/Indonesia" title="Indonesia">Indonesia</a>,
#  <a href="/wiki/Pakistan" title="Pakistan">Pakistan</a>,
#  <a href="/wiki/Turkey" title="Turkey">Turkey</a>,
#  <a href="/wiki/Myanmar" title="Myanmar">Myanmar</a>,
#  <a href="/wiki/Afghanistan" title="Afghanistan">Afghanistan</a>,
#  <a href="/wiki/Yemen" title="Yemen">Yemen</a>,
# ...

# %%
# Ns allons extraire à partir de ces liens la liste des countries
countries = [ ]
for link in links : 
    countries.append(link.get('title'))

print(countries)
# Out:
# ['Russia', 'European Russia', None, 'China', 'Hong Kong', 'Macau', 'India', 'Kazakhstan', 'Saudi Arabia', 'Iran', 'Mongolia', 'Indonesia', 'Pakistan', 'Turkey', 'Myanmar', 'Afghanistan', 'Yemen', 'Thailand', 'Turkmenistan', 'Uzbekistan', 'Iraq', 'Japan', 'Vietnam', 'Malaysia', 'Oman', 'Philippines', 'Laos', 'Kyrgyzstan', 'Syria', 'Golan Heights', 'Cambodia', 'Bangladesh', 'Nepal', 'Tajikistan', 'North Korea', 'South Korea', 'Jordan', 'Azerbaijan', 'Caucasus', 'Europe', 'Asia', 'United Arab Emirates', 'Georgia (country)', 'Caucasus', 'Europe', 'Asia', 'Sri Lanka', 'Bhutan', 'Taiwan', 'Armenia', 'Caucasus', 'Europe', 'Asia', 'Israel', 'Kuwait', 'East Timor', 'Qatar', 'Lebanon', 'Cyprus', 'Northern Cyprus', 'Brunei', 'Bahrain', 'Singapore', 'Maldives']

# %%
# Ns stockons le résultat ds 1 df
import pandas as pd
df = pd.DataFrame()
df['country'] = countries
df
# Out:
#                  country
# 0                 Russia
# 1                   None
# 2                  China
# 3              Hong Kong
# 4                  Macau
# 5                  India
# 6                   None
# 7             Kazakhstan
# 8           Saudi Arabia
# 9                   Iran
# 10              Mongolia
# 11             Indonesia
# 12              Pakistan
# 13      Gilgit-Baltistan
# 14          Azad Kashmir
# 15                Turkey
# 16               Myanmar
# 17           Afghanistan
# 18                 Yemen
# 19              Thailand
# 20          Turkmenistan
# 21            Uzbekistan
# 22                  Iraq
# 23                 Japan
# 24               Vietnam
# 25              Malaysia
# 26                  Oman
# 27           Philippines
# 28                  Laos
# 29            Kyrgyzstan
# 30                 Syria
# 31         Golan Heights
# 32              Cambodia
# 33            Bangladesh
# 34                 Nepal
# 35            Tajikistan
# ...

# %% [markdown]
# # Autre exemple : scraping a table

# %%
url = "https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2016-2017"
html = urlopen(url)
html_str = html.read()
soup = BeautifulSoup(html_str, 'lxml')
print(soup)
soup.title.text
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>Championnat de France de football 2016-2017 — Wikipédia</title>
# ...

# %%
# Q : A qoui sert has_attr()
table1 = soup.find("table") ; print(table1)
print(table1.has_attr(table1))
table1.attrs
print(table1.has_attr("liste_equipe"))
# Out:
# <table><caption style="background:#99cc99;color:#000000;">Généralités</caption><tbody><tr>
# <th scope="row" style="width:10.5em;">Sport</th>
# <td>
# <a href="/wiki/Football" title="Football">Football</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Organisateur(s)</th>
# <td>
# <a href="/wiki/Ligue_de_football_professionnel" title="Ligue de football professionnel">LFP</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Édition</th>
# <td>
# <abbr class="abbr" title="Soixante-dix-neuvième (septante-neuvième)">79<sup>e</sup></abbr></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Lieu(x)</th>
# <td>
# ...

# %%
# Q : Cmnt tu affiche l'attribut d'un tag ?
tableAll = soup.findAll("table")
for table in tableAll : 
    print('* ', table.attrs)
# Out:
# *  {}
# *  {}
# *  {}
# *  {'cellspacing': '0', 'align': 'center', 'style': 'width:0px;'}
# *  {'class': ['DebutCarte'], 'style': 'width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center; font-size:72%; line-height:1.1em;'}
# *  {'class': ['wikitable', 'sortable'], 'style': 'font-size:90%;line-height:15px;'}
# *  {'class': ['wikitable', 'sortable']}
# *  {'class': ['wikitable', 'gauche'], 'style': 'text-align:center; line-height:16px;'}
# *  {'class': ['wikitable'], 'style': 'text-align:center; line-height:16px; font-size:90%; margin-top: 0em;'}
# *  {'width': '100%', 'style': 'line-height:1.4; margin-bottom:0.0em; border-spacing:0px 2px; background:#f9f9f9;', 'id': 'T1M1', 'class': ['collapsible', 'collapsed']}
# *  {'width': '100%', 'style': 'line-height:1.4; margin-bottom:0.0em; border-spacing:0px 2px; background:#f9f9f9;', 'id': 'T1M1', 'class': ['collapsible', 'collapsed']}
# *  {'width': '100%'}
# ...

# %%
table_map = soup.find("table", {"class" : 'DebutCarte'}) 
print(table_map.prettify())
# Out:
# <table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center; font-size:72%; line-height:1.1em;">
#  <tr>
#   <td style="border:none; padding:0">
#    <div style="position:relative;;">
#     <a class="image" href="/wiki/Fichier:France_location_map-Regions-2016.svg">
#      <img alt="France location map-Regions-2016.svg" data-file-height="1922" data-file-width="2000" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/300px-France_location_map-Regions-2016.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/450px-France_location_map-Regions-2016.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/600px-France_location_map-Regions-2016.svg.png 2x" width="300"/>
#     </a>
# ...

# %%
# liste_equipe = soup.find("table", {"class" : "wikitable sortable jquery-tablesorter"})
# S : KO ! Tu as copier/coller le nom complet de la class de la table comme elle s'affiche sur chrome.
# Alorq tu dois t'arreter "wikitable sortable", cet info tu la trouve ds le Ctrl-U.
liste_equipe = soup.find("table", {'class': 'wikitable sortable'}) 
# liste_equipe = soup.find("table", {'class': ['wikitable', 'sortable'], 'style': 'font-size:90%;line-height:15px;'})
# S : Tu determine l'attribut à l'aide table.attrs
print(liste_equipe)
# print(liste_equipe.attrs)
# all_tables = soup.findAll("table")
# len(all_tables) # 32 tables
# Out:
# <table class="wikitable sortable" style="font-size:90%;line-height:15px;">
# <tbody><tr>
# <th>Club</th>
# <th>Dernière <br/>montée</th>
# <th><abbr title="{{{2}}}">Budget</abbr><br/> en M<a href="/wiki/Euro" title="Euro">€</a><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite_crochet">[</span>1<span class="cite_crochet">]</span></a></sup></th>
# <th>Classement<br/><a href="/wiki/Championnat_de_France_de_football_2015-2016" title="Championnat de France de football 2015-2016">2015-2016</a></th>
# <th>Entraîneur</th>
# <th>Depuis</th>
# <th>Stade</th>
# <th>Capacité<br/>théorique</th>
# <th>Nombre de saisons <br/>en Ligue 1
# </th></tr>
# <tr bgcolor="#97DEFF">
# <td align="center"><a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a></td>
# <td align="center">1974</td>
# <td align="center">503</td>
# ...

# %%
# Cmnt exécuter une regex ds la recherche des url
import re
txt = '\w+'
# club = table_map.findAll('a')
club = table_map.findAll('a', {'title': txt})
# , text = 'title'
# clubs = club[1 : len(club)-1] 
for i in club : 
    print('*', i.attrs)
# print(club1)

# %%
type(table_map.get_text(strip = True))
table_map.get_text(strip = True)
# Out:
# 'Paris SGAS Monaco FCOlympique lyonnaisStade rennais FCOGC NiceAS Saint-ÉtienneDijon FCOAngers SCOLille OSCSM CaenAS Nancy-LorraineFC NantesMontpellier HSCFC Girondins de BordeauxSC BastiaEA GuingampFC LorientOlympique deMarseilleFC MetzToulouse FC'

# %%
for item in table_map.find_all('a') : 
    print(item.get('href'))
# Out:
# /wiki/Fichier:France_location_map-Regions-2016.svg
# /wiki/Paris_Saint-Germain_Football_Club
# /wiki/Association_sportive_de_Monaco_football_club
# /wiki/Olympique_lyonnais
# /wiki/Stade_rennais_football_club
# /wiki/Olympique_gymnaste_club_Nice_C%C3%B4te_d%27Azur
# /wiki/Association_sportive_de_Saint-%C3%89tienne
# /wiki/Dijon_Football_C%C3%B4te-d%27Or
# /wiki/Angers_sporting_club_de_l%27Ouest
# /wiki/LOSC_Lille
# /wiki/Stade_Malherbe_Caen_Calvados_Basse-Normandie
# /wiki/Association_sportive_Nancy-Lorraine
# /wiki/Football_Club_de_Nantes
# /wiki/Montpellier_H%C3%A9rault_Sport_Club
# /wiki/Football_Club_des_Girondins_de_Bordeaux
# /wiki/Sporting_Club_de_Bastia
# /wiki/En_Avant_de_Guingamp
# /wiki/Football_Club_Lorient-Bretagne_Sud
# /wiki/Olympique_de_Marseille
# /wiki/Football_Club_de_Metz
# /wiki/Toulouse_Football_Club

# %%
<a class="image" href="/wiki/Fichier:France_location_map-Regions-2016.svg"><img alt="France location map-Regions-2016.svg" data-file-height="1922" data-file-width="2000" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/300px-France_location_map-Regions-2016.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/450px-France_location_map-Regions-2016.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/600px-France_location_map-Regions-2016.svg.png 2x" width="300"/></a>
-------
<a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris SG</a>
-------
<a href="/wiki/Association_sportive_de_Monaco_football_club" title="Association sportive de Monaco football club">AS Monaco FC</a>
-------
<a href="/wiki/Olympique_lyonnais" title="Olympique lyonnais">Olympique lyonnais</a>
-------
<a href="/wiki/Stade_rennais_football_club" title="Stade rennais football club">Stade rennais FC</a>
-------

# %%
wiki = "http://en.wikipedia.org/wiki/List_of_postcode_districts_in_the_United_Kingdom"
page = urlopen(wiki)
html = page.read()
soup = BeautifulSoup(html, 'lxml')
# print(soup)
table = soup.find("table", { "class" : "wikitable sortable" })
print (table)

# %%
# Pokémon 
import requests
req = 'http://pokemondb.net/pokedex/national'
r = requests.get(req)
page = BeautifulSoup(r.text, "lxml")
# html = urlopen(req)
# page = BeautifulSoup(html.read(), "lxml")

# %%
# récupérer la liste des noms de pokémon
liste_pokemon = []
for pokemon in page.findAll('span', {'class' : 'infocard-lg-img'}) : 
    pokemon = pokemon.find('a').get('href').replace("/pokedex/",'')
    liste_pokemon.append(pokemon)

# %%
liste_pokemon
# Out:
# ['bulbasaur',
#  'ivysaur',
#  'venusaur',
#  'charmander',
#  'charmeleon',
#  'charizard',
#  'squirtle',
#  'wartortle',
#  'blastoise',
#  'caterpie',
#  'metapod',
#  'butterfree',
#  'weedle',
#  'kakuna',
#  'beedrill',
#  'pidgey',
#  'pidgeotto',
#  'pidgeot',
#  'rattata',
#  'raticate',
#  'spearow',
#  'fearow',
#  'ekans',
#  'arbok',
#  'pikachu',
#  'raichu',
#  'sandshrew',
#  'sandslash',
#  'nidoran-f',
#  'nidorina',
#  'nidoqueen',
#  'nidoran-m',
#  'nidorino',
#  'nidoking',
#  'clefairy',
#  'clefable',
#  'vulpix',
#  'ninetales',
#  'jigglypuff',
#  'wigglytuff',
#  'zubat',
#  'golbat',
#  'oddish',
#  'gloom',
#  'vileplume',
#  'paras',
#  'parasect',
#  'venonat',
#  'venomoth',
#  'diglett',
#  'dugtrio',
#  'meowth',
#  'persian',
#  'psyduck',
#  'golduck',
#  'mankey',
#  'primeape',
#  'growlithe',
#  'arcanine',
#  'poliwag',
#  'poliwhirl',
#  'poliwrath',
#  'abra',
#  'kadabra',
#  'alakazam',
#  'machop',
#  'machoke',
#  'machamp',
# ...

# %%
## Fonction pour obtenir les caractéristiques de pokemons
def get_page(pokemon_name):
    url_pokemon = 'http://pokemondb.net/pokedex/'+ pokemon_name
    req = urllib.request.Request(url_pokemon, headers = {'User-Agent' : 'Mozilla/5.0'})
    html = urllib.request.urlopen(req).read()
    return bs4.BeautifulSoup(html, "lxml")

# %%
def get_cara_pokemon(pokemon_name):
    page = get_page(pokemon_name)
    data = collections.defaultdict()
     # table Pokédex data, Training, Breeding, base Stats
    
    for table in page.findAll('table', { 'class' : "vitals-table"})[0:4] :
        table_body = table.find('tbody')
        for rows in table_body.findChildren(['tr']) : 
            if len(rows) > 1 : # attention aux tr qui ne contiennent rien
                column = rows.findChild('th').getText()
                cells = rows.findChild('td').getText()
                cells = cells.replace('\t','').replace('\n',' ')
                data[column] = cells
                data['name'] = pokemon_name
    return dict(data)
       
items = []       
for e, pokemon in enumerate(liste_pokemon) : 
    print(e, pokemon)
    item = get_cara_pokemon(pokemon)       
    items.append(item)
    if e > 20:
        break
df = pd.DataFrame(items)
df.head()
# Out:
# 0 bulbasaur
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-5da529c99bb8> in <module>()
#      18 for e, pokemon in enumerate(liste_pokemon) :
#      19     print(e, pokemon)
# ---> 20     item = get_cara_pokemon(pokemon)
#      21     items.append(item)
#      22     if e > 20:
#
# <ipython-input-129-5da529c99bb8> in get_cara_pokemon(pokemon_name)
#       1 def get_cara_pokemon(pokemon_name):
# ----> 2     page = get_page(pokemon_name)
#       3     data = collections.defaultdict()
#       4      # table Pokédex data, Training, Breeding, base Stats
#       5
#
# <ipython-input-127-a28549b560ff> in get_page(pokemon_name)
#       2 def get_page(pokemon_name):
#       3     url_pokemon = 'http://pokemondb.net/pokedex/'+ pokemon_name
# ----> 4     req = urllib.request.Request(url_pokemon, headers = {'User-Agent' : 'Mozilla/5.0'})
# ...

# %% [markdown]
# # Solution express en utilisant Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# https://pbpython.com/pandas-html-table.html

table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')
table_MN
df = table_MN[0]
df.head()
# Out:
#    Year     Office    GOP    DFL Others
# 0  2020  President  45.3%  52.4%   2.3%
# 1  2020    Senator  43.5%  48.8%   7.7%
# 2  2018   Governor  42.4%  53.9%   3.7%
# 3  2018    Senator  36.2%  60.3%   3.4%
# 4  2018    Senator  42.4%  53.0%   4.6%
