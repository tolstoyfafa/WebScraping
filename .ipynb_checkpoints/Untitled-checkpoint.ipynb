# %%
# This notebook have as a point to allow us scraping job sites, to give us ability to have a DB that references 
# all available computing jobs in France.
# Steps:
"""
Search on :
- indeed
- monster
with keys {'informatique', 'france'} 
- Find where is job ads 
- parse and get {title, salary, location, missions, company name}
"""
#!pip install pandas
# !pip install bs4 requests lxml
# Out:
# Processing /home/fbordjah/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472/bs4-0.0.1-cp36-none-any.whl
# Collecting requests
#   Using cached requests-2.25.0-py2.py3-none-any.whl (61 kB)
# Collecting lxml
#   Using cached lxml-4.6.1-cp36-cp36m-manylinux1_x86_64.whl (5.5 MB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2020.11.8-py2.py3-none-any.whl (155 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4, urllib3, idna, certifi, chardet, requests, lxml
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 certifi-2020.11.8 chardet-3.0.4 idna-2.10 lxml-4.6.1 requests-2.25.0 soupsieve-2.0.1 urllib3-1.26.2
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/fbordjah/.virtualenvs/scraping_project/bin/python -m pip install --upgrade pip' command.

# %%
# Brouillon
#!conda install lxml requests bs4
#!conda install -y pandas
#!pip install pandas

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# search for jobs with key 'inforamtique' and 'france' location.

indeed_url = "https://fr.indeed.com/emplois?q=informatique&l=France"
res = requests.get("https://fr.indeed.com/emplois?q=informatique&l=France")
# print(res)
# parse witrh soup
soup = bs(res.content,"html")
#print(type(soup))
cards = soup.find_all({"div"},{"class":"jobsearch-SerpJobCard unifiedRow row result"})
subjects = []
companies = []
for card in cards:
    draft = card.h2.a.text
    result = draft.replace('\n','')
    subjects.append(result)
    draf2 = card.find({"div"},{"class":"sjcl"}).span.text
    result2 = draf2.lstrip('\n')
    companies.append(result2)
df = pd.DataFrame(zip(subjects,companies),columns=('Job','Company'))
df
# Out:
#                                                   Job                 Company
# 0                          Ingénieur informatique H/F             IT SYSTEMES
# 1   TECHNICIEN INFORMATIQUE - PROJETS & PROXIMITÉ ...                 IZENCIA
# 2                           Assureur Qualité Systèmes                 Guerbet
# 3                         Technicien Informatique H/F               Stokomani
# 4   TECHNICIEN INFORMATIQUE - SUPPORT HELP DESK (F/H)                 IZENCIA
# 5                 Technicien support informatique H/F  Promosoft Informatique
# 6              technicien(ne) assistance informatique       ordre des avocats
# 7   Ingénieur / Ingénieure d'étude et développemen...             Pôle Emploi
# 8                   Chef de projet informatique - H/F             ICF HABITAT
# 9              Techniciens Support Informatique (H/F)                   Yatic
# 10                 Technicien systèmes et réseaux H/F                  QIONIS
# 11                           RESPONSABLE INFORMATIQUE     CPAM D'EURE-ET-LOIR
# 12                        Technicien informatique H/F                CONCEPTA
# 13     Technicien Support Informatique F/H - CDD 1 an                 Ubisoft
# 14  Technicien de proximité informatique N2 H/F - ...    Rio Managed Services
# 15      Technicien support de parc informatique — H/F              Aléo Santé
# 16              TECHNICIEN SUPPORT INFORMATIQUE (H/F)   BASYS IT-Service GmbH
# 17  TECHNICIEN INFORMATIQUE - PILOTE D’EXPLOITATIO...                 IZENCIA
